# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\dataset_olympics.csv')

# %%
data.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      70000 non-null  int64
#  1   Name    70000 non-null  object
#  2   Sex     70000 non-null  object
#  3   Age     67268 non-null  float64
#  4   Height  53746 non-null  float64
#  5   Weight  52899 non-null  float64
#  6   Team    70000 non-null  object
#  7   NOC     70000 non-null  object
#  8   Games   70000 non-null  object
#  9   Year    70000 non-null  int64
#  10  Season  70000 non-null  object
#  11  City    70000 non-null  object
#  12  Sport   70000 non-null  object
#  13  Event   70000 non-null  object
#  14  Medal   9690 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 8.0+ MB

# %%
data.describe()
# Out:
#                  ID           Age        Height        Weight          Year
# count  70000.000000  67268.000000  53746.000000  52899.000000  70000.000000
# mean   18081.846986     25.644645    175.505303     70.900216   1977.766457
# std    10235.613253      6.485239     10.384203     14.217489     30.103306
# min        1.000000     11.000000    127.000000     25.000000   1896.000000
# 25%     9325.750000     21.000000    168.000000     61.000000   1960.000000
# 50%    18032.000000     25.000000    175.000000     70.000000   1984.000000
# 75%    26978.000000     28.000000    183.000000     79.000000   2002.000000
# max    35658.000000     88.000000    223.000000    214.000000   2016.000000

# %%
data.describe(include='object')
# Out:
#                                     Name    Sex           Team    NOC  \
# count                              70000  70000          70000  70000
# unique                             35556      2            827    226
# top     Oksana Aleksandrovna Chusovitina      M  United States    USA
# freq                                  29  51877           4979   5216
#
#               Games  Season    City      Sport                    Event Medal
# count         70000   70000   70000      70000                    70000  9690
# unique           51       2      42         65                      744     3
# top     2016 Summer  Summer  London  Athletics  Football Men's Football  Gold
# freq           3675   58467    6034      10629                     1738  3292

# %%
data.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2732
# Height    16254
# Weight    17101
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     60310
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 383

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data['Year'].describe()
# Out:
# count    70000.000000
# mean      1977.766457
# std         30.103306
# min       1896.000000
# 25%       1960.000000
# 50%       1984.000000
# 75%       2002.000000
# max       2016.000000
# Name: Year, dtype: float64

# %%
data['Year'].nunique()
# Out:
# 35

# %%
data.shape
# Out:
# (70000, 15)

# %%
data['Year'].unique()
# Out:
# array([1992, 2012, 1920, 1900, 1988, 1994, 1932, 2002, 1952, 1980, 2000,
#        1996, 1912, 1924, 2014, 1948, 1998, 2006, 2008, 2016, 2004, 1960,
#        1964, 1984, 1968, 1972, 1936, 1956, 1928, 1976, 2010, 1906, 1904,
#        1908, 1896], dtype=int64)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (69617, 15)

# %%
data.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2671
# Height    15876
# Weight    16718
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     59931
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
ax=sns.countplot(x='Sex',data=data,palette='CMRmap')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Contribution of Male and Female participants in Olympic game')
plt.xlabel('Number of Male and Female')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20100\2984081478.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='Sex',data=data,palette='CMRmap')

# %%
sns.histplot(x='Age',data=data,bins=10,kde=True)
plt.title('Distribution of Ages in Olympic participants')
plt.shoW()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 3
#       1 sns.histplot(x='Age',data=data,bins=10,kde=True)
#       2 plt.title('Distribution of Ages in Olympic participants')
# ----> 3 plt.shoW()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'shoW'

# %%
sns.histplot(x='Height',data=data,bins=20,kde=True)
plt.title('Height distribution of Olympic participants')
plt.show()

# %%
sns.histplot(x='Weight',data=data,bins=20,kde=True)
plt.title('Weight distribution')
plt.show()

# %%
ax=sns.countplot(x='Medal',data=data,palette='Dark2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Medals Distribution')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20100\555828257.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='Medal',data=data,palette='Dark2')

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Year',data=data,hue='Medal',palette='Dark2')
plt.title('Medal distribution in each year')
plt.xticks(rotation=45)
plt.show()

# %%
avg_year_data=data.groupby('Year',as_index=False)['Age'].mean().sort_values(by='Age',ascending=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Year',y='Age',data=avg_year_data,palette='Paired')
plt.title('Average Age of participants in every year')
plt.xlabel('Year')
plt.ylabel('Average Age')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20100\989381790.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year',y='Age',data=avg_year_data,palette='Paired')

# %%
data['Sport'].nunique()
# Out:
# 65

# %%
sport_median_height=data.groupby('Sport',as_index=False)['Height'].median().sort_values(by='Height',ascending=False).head(20)

# %%
sport_median_height
# Out:
#                 Sport  Height
# 7          Basketball   190.0
# 61         Volleyball   187.5
# 9    Beach Volleyball   187.0
# 62         Water Polo   185.0
# 42             Rowing   185.0
# 3    Art Competitions   183.0
# 6            Baseball   183.0
# 60         Tug-Of-War   182.0
# 27           Handball   182.0
# 11          Bobsleigh   181.0
# 57             Tennis   180.0
# 13           Canoeing   180.0
# 32           Lacrosse   180.0
# 35  Modern Pentathlon   179.0
# 29         Ice Hockey   179.0
# 37    Nordic Combined   178.0
# 33               Luge   178.0
# 53           Swimming   178.0
# 45            Sailing   178.0
# 49        Ski Jumping   178.0

# %%
data.groupby('Sport',as_index=False)['Height'].median().sort_values(by='Height',ascending=False).tail(20)
# Out:
#                         Sport  Height
# 47  Short Track Speed Skating   170.0
# 51                   Softball   170.0
# 55               Table Tennis   170.0
# 54      Synchronized Swimming   168.0
# 22             Figure Skating   168.0
# 63              Weightlifting   168.0
# 40        Rhythmic Gymnastics   167.0
# 19                     Diving   166.0
# 58               Trampolining   165.0
# 26                 Gymnastics   164.0
# 1                    Alpinism     NaN
# 8               Basque Pelota     NaN
# 14                    Cricket     NaN
# 15                    Croquet     NaN
# 30               Jeu De Paume     NaN
# 34        Military Ski Patrol     NaN
# 36               Motorboating     NaN
# 38                       Polo     NaN
# 39                   Racquets     NaN
# 41                      Roque     NaN

# %%
sport_median_height['Height'].mean()
# Out:
# 181.675

# %%
sport_median_height.max()
# Out:
# Sport     Water Polo
# Height         190.0
# dtype: object

# %%
sport_median_height.min()
# Out:
# Sport     Art Competitions
# Height               178.0
# dtype: object

# %%
plt.figure(figsize=(15,6))
ax=sns.barplot(x='Sport',y='Height',data=sport_median_height,palette='Purples_d')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Top 20 Median Height of the sports person in 20 sports')
plt.xlabel('Sports Name')
plt.ylabel('Median Height')
plt.xticks(rotation=70)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20100\3248348605.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x='Sport',y='Height',data=sport_median_height,palette='Purples_d')

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.groupby(['NOC','Sex'])['ID'].count()
# Out:
# NOC  Sex
# AFG  M       38
# AHO  F        6
#      M       27
# ALB  F        4
#      M        7
#            ...
# YUG  M      455
# ZAM  F        3
#      M       40
# ZIM  F       41
#      M       47
# Name: ID, Length: 432, dtype: int64

# %%
data['Medal'].value_counts()
# Out:
# Medal
# Gold      3290
# Bronze    3208
# Silver    3188
# Name: count, dtype: int64

# %%
data[data['Medal']=='Gold'].groupby('NOC')['Medal'].count().sort_values(ascending=False).tail(20)
# Out:
# NOC
# INA    2
# IRL    2
# PRK    2
# GEO    1
# UGA    1
# ARM    1
# LUX    1
# AZE    1
# MGL    1
# CIV    1
# JOR    1
# COL    1
# UAE    1
# NEP    1
# THA    1
# IRI    1
# DOM    1
# IOA    1
# POR    1
# ALG    1
# Name: Medal, dtype: int64

# %%
gold_madel_woner=data[data['Medal']=='Gold'].groupby('NOC')['Medal'].count().sort_values(ascending=False).head(10)

# %%
ax=gold_madel_woner.plot(kind='bar')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Top 10 gold Medal woner country in Olympic')
plt.xlabel('Name of Country')
plt.ylabel('Number of Gold Medal')
plt.show()

# %%
avg_weight_gender=data.groupby(['Sport','Sex'])['Weight'].mean()

# %%
data['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
avg_weight_gender['Wrestling']
# Out:
# Sex
# F    58.169014
# M    77.256240
# Name: Weight, dtype: float64

# %%
avg_weight_gender['Wrestling']['M']
# Out:
# 77.25624024960999

# %%
sport_event_count=data.groupby('Sport')['Event'].nunique().sort_values(ascending=False)

# %%
sport_event_count.head(10)
# Out:
# Sport
# Athletics           83
# Shooting            81
# Swimming            54
# Cycling             42
# Sailing             37
# Wrestling           29
# Art Competitions    28
# Canoeing            27
# Gymnastics          26
# Rowing              25
# Name: Event, dtype: int64

# %%
sport_event_count.head(10).plot(kind='bar')
plt.title('Top 10 unique events per sports')
plt.xlabel('Sport')
plt.ylabel('Count of Events')
plt.xticks(rotation=70)
plt.show()

# %%
data.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
top_participation=data.groupby('Year',as_index=False)['ID'].nunique().sort_values(by='ID',ascending=False)

# %%
plt.figure(figsize=(20,6))
ax=sns.barplot(x='Year',y='ID',data=top_10_participation,palette='Set1')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Participations in every Olympic')
plt.xlabel('Year')
plt.ylabel('Number of Participants')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20100\4099845474.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x='Year',y='ID',data=top_10_participation,palette='Set1')

# %%
#top_10_participation.plot(kind='line',marker='o')
top_10_participation=data.groupby('Year')['ID'].nunique()
top_10_participation.plot(kind='line',marker='o')
plt.title('Number of Participations in Olympic')
plt.xlabel('Year')
plt.ylabel('Number of Participants')
plt.show()

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
#country_average_age
country_average_age=data.groupby('NOC',as_index=False)['Age'].mean().sort_values(by='Age',ascending=False).head(10)

# %%
plt.figure(figsize=(16,6))
ax=sns.barplot(x='NOC',y='Age',data=country_average_age,palette='bwr')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Top 10 countries participants with highest average age')
plt.xlabel('Country Name')
plt.ylabel('Average Age')
plt.xticks(rotation=70)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16560\1495779154.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x='NOC',y='Age',data=country_average_age,palette='bwr')

# %%
country_average_lowest_age=data.groupby('NOC',as_index=False)['Age'].mean().sort_values(by='Age').head(10)

# %%
data.groupby('NOC',as_index=False)['Age'].mean().sort_values(by='Age').head(10)
# Out:
#      NOC        Age
# 108  KIR  17.000000
# 112  LAO  20.000000
# 222  YMD  20.000000
# 161  PRK  20.677419
# 127  MDV  20.833333
# 214  VAN  20.857143
# 187  SUR  20.888889
# 45   COK  21.000000
# 204  TUV  21.000000
# 216  VIE  21.052632

# %%
plt.figure(figsize=(10,4))
ax=sns.barplot(x='NOC',y='Age',data=country_average_lowest_age,palette='bwr')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Top 10 countries participants with lowest average age')
plt.xlabel('Country Name')
plt.ylabel('Average Age')
plt.xticks(rotation=70)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16560\3176907814.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x='NOC',y='Age',data=country_average_lowest_age,palette='bwr')

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
sns.boxplot(x='Season',y='Age',data=data,palette='cividis')
plt.title('Distribution of Ages by Season')
plt.xlabel('Season')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16560\718151222.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Season',y='Age',data=data,palette='cividis')

# %%
sns.violinplot(x='Medal',y='Height',data=data,palette='cool')
plt.title('Distribution of Heights by Medal')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16560\1919618721.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Medal',y='Height',data=data,palette='cool')

# %%
data['NOC'].value_counts().idxmax()
# Out:
# 'USA'

# %%
print('Most medal winning country:',data['NOC'].value_counts().idxmax())
# Out:
# Most medal winning country: USA

# %%
tallest_height=data[data['Height']==data['Height'].max()]

# %%
tallest_height
# Out:
#           ID                  Name Sex   Age  Height  Weight           Team  \
# 32376  16639  Tommy Loren Burleson   M  20.0   223.0   102.0  United States
#
#        NOC        Games  Year  Season    City       Sport  \
# 32376  USA  1972 Summer  1972  Summer  Munich  Basketball
#
#                              Event   Medal
# 32376  Basketball Men's Basketball  Silver

# %%
heaviest_athelete=data[data['Weight']==data['Weight'].max()]

# %%
heaviest_athelete
# Out:
#           ID               Name Sex   Age  Height  Weight  Team  NOC  \
# 23155  12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM
# 23156  12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM
#
#              Games  Year  Season     City Sport                   Event Medal
# 23155  2008 Summer  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 23156  2012 Summer  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
thinnest_athelete=data[data['Weight']==data['Weight'].min()]

# %%
thinnest_athelete[['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games']]
# Out:
#           ID            Name Sex   Age  Height  Weight         Team  NOC  \
# 40849  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40850  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40851  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40852  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40853  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40854  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
#
#              Games
# 40849  1980 Summer
# 40850  1980 Summer
# 40851  1980 Summer
# 40852  1980 Summer
# 40853  1980 Summer
# 40854  1980 Summer

# %%
sns.scatterplot(x='Height',y='Weight',hue='Medal',palette='gist_ncar',data=data)
plt.title('Athlete Height vs weight by Medal status')
plt.show()

# %%
medals_by_country_year=data.pivot_table(index='NOC',columns='Year',values='Medal',aggfunc='count')
sns.heatmap(medals_by_country_year,linewidths=0.5)
plt.title('Medal Counts by Country and Year')
plt.xlabel('Year')
plt.ylabel('Country')
plt.sticks(rotation=70)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[242], line 6
#       4 plt.xlabel('Year')
#       5 plt.ylabel('Country')
# ----> 6 plt.sticks(rotation=70)
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sticks'
